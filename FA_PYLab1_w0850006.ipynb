# %%
import numpy as np
import pandas as pd

# %%
## Read in Excel - city.xls
df1 = pd.read_excel('/content/City.xls')
df1.head()
# Out:
#      MV  INDUS   NOX     RM  TAX    PT  LSTAT  Unnamed: 7  Unnamed: 8  \
# 0  24.0   2.31  53.8  6.575  296  15.3   4.98         NaN         NaN
# 1  21.6   7.07  46.9  6.421  242  17.8   9.14         NaN         NaN
# 2  34.7   7.07  46.9  7.185  242  17.8   4.03         NaN         NaN
# 3  33.4   2.18  45.8  6.998  222  18.7   2.94         NaN         NaN
# 4  36.2   2.18  45.8  7.147  222  18.7   5.33         NaN         NaN
#
#                          Unnamed: 9
# 0    Subset of Boston housing tract
# 1    data of Harrison and Rubinfeld
# 2    (1978).  Each case is one U.S.
# 3  Census tract in the Boston area.
# 4                               NaN

# %%
# Load a sheet into a DataFrame by name: df1 and read head
df1 = pd.read_excel('/content/City.xls')
df1.head()
# Out:
#      MV  INDUS   NOX     RM  TAX    PT  LSTAT  Unnamed: 7  Unnamed: 8  \
# 0  24.0   2.31  53.8  6.575  296  15.3   4.98         NaN         NaN
# 1  21.6   7.07  46.9  6.421  242  17.8   9.14         NaN         NaN
# 2  34.7   7.07  46.9  7.185  242  17.8   4.03         NaN         NaN
# 3  33.4   2.18  45.8  6.998  222  18.7   2.94         NaN         NaN
# 4  36.2   2.18  45.8  7.147  222  18.7   5.33         NaN         NaN
#
#                          Unnamed: 9
# 0    Subset of Boston housing tract
# 1    data of Harrison and Rubinfeld
# 2    (1978).  Each case is one U.S.
# 3  Census tract in the Boston area.
# 4                               NaN

# %%
#Read in a very simple CSV file and read head

df2=pd.read_csv('/content/StockData.csv')
df2.head()
# Out:
#   Ticker              Name                  Sector  Beta  Market Cap  \
# 0   AAPL         APPLE INC  Information Technology  1.09  1081130615
# 1   AMZN    AMAZON.COM INC  Consumer Discretionary  1.23   960942834
# 2   MSFT    MICROSOFT CORP  Information Technology  1.46   869345788
# 3  GOOGL    ALPHABET INC-A  Information Technology  1.44   817459888
# 4  BRK/A  BERKSHIRE HATH-A              Financials  1.13   534247506
#
#    Current Price  Price Target
# 0         223.84        232.27
# 1        1970.19       2133.39
# 2         113.37        122.30
# 3        1177.98       1384.89
# 4      324999.00     357125.00

# %%
#Read in CSV when the seperator is ;
df3=pd.read_csv('/content/StockData.csv',sep=';')
df3.head()
# Out:
#   Ticker,Name,Sector,Beta,Market Cap,Current Price,Price Target
# 0  AAPL,APPLE INC,Information Technology,1.09,108...
# 1  AMZN,AMAZON.COM INC,Consumer Discretionary,1.2...
# 2  MSFT,MICROSOFT CORP,Information Technology,1.4...
# 3  GOOGL,ALPHABET INC-A,Information Technology,1....
# 4  BRK/A,BERKSHIRE HATH-A,Financials,1.13,5342475...

# %%
#Read in .txt file

file_path = "/content/InfoTxt.txt"

df4 = pd.read_csv(file_path)
print(df4.head())
# Out:
#          MV\tINDUS\tNOX\tRM\tTAX\tPT\tLSTAT
# 0    24\t2.31\t53.8\t6.575\t296\t15.3\t4.98
# 1  21.6\t7.07\t46.9\t6.421\t242\t17.8\t9.14
# 2  34.7\t7.07\t46.9\t7.185\t242\t17.8\t4.03
# 3  33.4\t2.18\t45.8\t6.998\t222\t18.7\t2.94
# 4  36.2\t2.18\t45.8\t7.147\t222\t18.7\t5.33

# %%
## Read in HTML data
import html5lib

# %%
# specify the html to be read in - 'https://en.wikipedia.org/wiki/Provinces_and_territories_of_Canada'
url = 'https://en.wikipedia.org/wiki/Provinces_and_territories_of_Canada'
html_data = pd.read_html(url)
df5=html_data[1]
df5.head()
# Out:
#   Name and postal abbr.                               Cities              \
#   Name and postal abbr. Name and postal abbr..1   Capital[7]  Largest[8]
# 0               Ontario                      ON      Toronto     Toronto
# 1                Quebec                      QC  Quebec City    Montreal
# 2           Nova Scotia                      NS   Halifax[c]  Halifax[c]
# 3         New Brunswick                      NB  Fredericton     Moncton
# 4              Manitoba                      MB     Winnipeg    Winnipeg
#
#   Entered Confederation[2] Official language(s)[3]     Population  \
#   Entered Confederation[2] Official language(s)[3] 2021 census[9]
# 0             July 1, 1867              English[a]       14223942
# 1             July 1, 1867               French[b]        8501833
# 2             July 1, 1867              English[a]         969383
# 3             July 1, 1867      English, French[d]         775610
# ...

# %%
 # #this is a list of dataframes
 sheets=[]
for var in dir():
    if isinstance(locals()[var], pd.core.frame.DataFrame)  and var[0]!='_':
        sheets.append(var)
print(sheets)
# Out:
# ['df', 'df1', 'df2', 'df3', 'df4', 'df5']

# %%
 #grab dataframe from index 0
df6=html_data[0]
df6.head()
# Out:
#   Provinces and territories of Canada Provinces and territories of Canada.1
# 0                                 NaN                                   NaN
# 1                            Category                       Federated state
# 2                              Number             10 provinces3 territories
# 3                          Government               Constitutional monarchy

# %%
# Another url

url = 'https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/'
url_data = pd.read_html(url)
df7=url_data[0]
df7.head()
# Out:
#                                Bank Name           City         State   Cert  \
# 0     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 1  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 2                          Citizens Bank       Sac City          Iowa   8758
# 3               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 4                    First Republic Bank  San Francisco    California  59017
#
#                  Aquiring Institution      Closing Date  Fund  Sort ascending
# 0  First Bank & Trust Co., Duncan, OK  October 18, 2024                 10547
# 1   Fulton Bank, National Association    April 26, 2024                 10546
# 2           Iowa Trust & Savings Bank  November 3, 2023                 10545
# 3              Dream First Bank, N.A.     July 28, 2023                 10544
# 4           JPMorgan Chase Bank, N.A.       May 1, 2023                 10543

# %%
 #list of dataframes
sheets=[]
for var in dir():
    if isinstance(locals()[var], pd.core.frame.DataFrame)  and var[0]!='_':
        sheets.append(var)
print(sheets)
# Out:
# ['df', 'df1', 'df2', 'df3', 'df4', 'df5', 'df6', 'df7', 'df8', 'historical_data', 'historical_data_meta', 'historical_data_microsoft']

# %%
# read with Yahoo Finance

import yfinance as yf
import pandas as pd
# Fetch data for a specific stock
ticker = "AAPL"
stock = yf.Ticker(ticker)

# Example: Fetch historical stock data
historical_data = stock.history(period="1y")
print(historical_data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-16 00:00:00-05:00  181.271937  183.361690  180.047923  182.734772
# 2024-01-17 00:00:00-05:00  180.386269  182.038164  179.420996  181.789383
# 2024-01-18 00:00:00-05:00  185.182793  188.217927  184.924066  187.710419
# 2024-01-19 00:00:00-05:00  188.406990  191.014212  187.899482  190.626114
# 2024-01-22 00:00:00-05:00  191.362503  194.377730  191.322690  192.944748
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-16 00:00:00-05:00  65603000        0.0           0.0
# 2024-01-17 00:00:00-05:00  47317400        0.0           0.0
# 2024-01-18 00:00:00-05:00  78005800        0.0           0.0
# 2024-01-19 00:00:00-05:00  68741000        0.0           0.0
# 2024-01-22 00:00:00-05:00  60133900        0.0           0.0

# %%
 ## aaple microsoft, facebook
 ticker_2 = "MSFT"  # Replace with your desired stock ticker
stock = yf.Ticker(ticker_2)

# Example: Fetch historical stock data
historical_data_microsoft = stock.history(period="1y")  # Get 1 year's worth of data

# Display the first few rows of historical data
print(historical_data_microsoft.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-16 00:00:00-05:00  390.738082  391.105331  384.742906  387.373230
# 2024-01-17 00:00:00-05:00  385.100262  387.214427  381.953778  386.579193
# 2024-01-18 00:00:00-05:00  388.812497  391.065638  387.224367  390.946533
# 2024-01-19 00:00:00-05:00  392.822503  395.710907  390.579268  395.710907
# 2024-01-22 00:00:00-05:00  397.050913  397.646466  390.668646  393.566986
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-16 00:00:00-05:00  27202300        0.0           0.0
# 2024-01-17 00:00:00-05:00  22234100        0.0           0.0
# 2024-01-18 00:00:00-05:00  23392100        0.0           0.0
# 2024-01-19 00:00:00-05:00  29272000        0.0           0.0
# 2024-01-22 00:00:00-05:00  27016900        0.0           0.0

# %%
# Fetch data for a specific stock
ticker_3 = "META"  # Replace with your desired stock ticker
stock = yf.Ticker(ticker_3)

# Example: Fetch historical stock data
historical_data_meta = stock.history(period="1y")  # Get 1 year's worth of data

# Display the first few rows of historical data
print(historical_data_meta.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-16 00:00:00-05:00  372.228123  374.180656  365.832571  366.061676
# 2024-01-17 00:00:00-05:00  364.906071  367.137567  357.245332  366.968201
# 2024-01-18 00:00:00-05:00  370.076312  375.415931  369.538389  374.698669
# 2024-01-19 00:00:00-05:00  377.557736  382.897325  376.531657  381.990814
# 2024-01-22 00:00:00-05:00  386.473682  388.864543  379.709513  380.327148
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-16 00:00:00-05:00  15306900        0.0           0.0
# 2024-01-17 00:00:00-05:00  12724800        0.0           0.0
# 2024-01-18 00:00:00-05:00  16354300        0.0           0.0
# 2024-01-19 00:00:00-05:00  21470100        0.0           0.0
# 2024-01-22 00:00:00-05:00  17680500        0.0           0.0

# %%
# !pip install quandl

# %%
##  https://www.quandl.com/
import quandl
#pip install quandl
import time

# %%
quandl.ApiConfig.api_key = 'nZ-7eoo3AsScgJcDsRXt' ##your API key here
##https://www.quandl.com/account/profile

# %%
#data = quandl.get("WIKI/AAPL", trim_start = "2019-12-31", trim_end = "2020-12-31")
data = quandl.get_table('WIKI/PRICES', ticker = ['AAPL', 'MSFT', 'FB'],
                        qopts = { 'columns': ['ticker', 'date', 'adj_close'] },
                        date = { 'gte': '2012-12-31', 'lte': '2013-12-31' },
                        paginate=True)
print(data)
# Out:
#      ticker       date  adj_close
# None
# 0      MSFT 2013-12-31  33.758397
# 1      MSFT 2013-12-30  33.650110
# 2      MSFT 2013-12-27  33.650110
# 3      MSFT 2013-12-26  33.785469
# 4      MSFT 2013-12-24  33.460608
# ...     ...        ...        ...
# 754    AAPL 2013-01-07  67.937002
# 755    AAPL 2013-01-04  68.338996
# 756    AAPL 2013-01-03  70.296565
# 757    AAPL 2013-01-02  71.195748
# 758    AAPL 2012-12-31  69.009795
#
# [759 rows x 3 columns]

# %%
## Read JSON file

import json
import pandas as pd

with open('/content/ProductJson.json', 'r', encoding='utf-8-sig') as file:
    data = json.load(file)
df = pd.DataFrame(data['Source Data'])
print(df.head())
# Out:
#         Product Customer    Qtr 2      Qtr 1      Qtr 4 Qtr 3
# 0  Alice Mutton    ANTON  $702.00        NaN        NaN   NaN
# 1  Alice Mutton    BERGS      NaN    $312.00        NaN   NaN
# 2  Alice Mutton    BOLID      NaN        NaN  $1,170.00   NaN
# 3  Alice Mutton    BOTTM      NaN  $1,170.00        NaN   NaN
# 4  Alice Mutton    ERNSH      NaN  $1,123.20  $2,607.15   NaN

# %%
# Opening JSON file

print(data)
# Out:
# {'Source Data': [{'Product': 'Alice Mutton', 'Customer': 'ANTON', 'Qtr 2': '$702.00'}, {'Product': 'Alice Mutton', 'Customer': 'BERGS', 'Qtr 1': '$312.00'}, {'Product': 'Alice Mutton', 'Customer': 'BOLID', 'Qtr 4': '$1,170.00'}, {'Product': 'Alice Mutton', 'Customer': 'BOTTM', 'Qtr 1': '$1,170.00'}, {'Product': 'Alice Mutton', 'Customer': 'ERNSH', 'Qtr 1': '$1,123.20', 'Qtr 4': '$2,607.15'}, {'Product': 'Alice Mutton', 'Customer': 'GODOS', 'Qtr 2': '$280.80'}, {'Product': 'Alice Mutton', 'Customer': 'HUNGC', 'Qtr 1': '$62.40'}, {'Product': 'Alice Mutton', 'Customer': 'PICCO', 'Qtr 2': '$1,560.00', 'Qtr 3': '$936.00'}, {'Product': 'Alice Mutton', 'Customer': 'RATTC', 'Qtr 2': '$592.80'}, {'Product': 'Alice Mutton', 'Customer': 'REGGC', 'Qtr 4': '$741.00'}, {'Product': 'Alice Mutton', 'Customer': 'SAVEA', 'Qtr 3': '$3,900.00', 'Qtr 4': '$789.75'}, {'Product': 'Alice Mutton', 'Customer': 'SEVES', 'Qtr 2': '$877.50'}, {'Product': 'Alice Mutton', 'Customer': 'WHITC', 'Qtr 4': '$780.00'}, 
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# returns JSON object as
# a dictionary
#data = json.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# ...

# %%
#print(data)
# Iterating through the json
# list

for entry in data['Source Data']:
    print(entry)
# Out:
# {'Product': 'Alice Mutton', 'Customer': 'ANTON', 'Qtr 2': '$702.00'}
# {'Product': 'Alice Mutton', 'Customer': 'BERGS', 'Qtr 1': '$312.00'}
# {'Product': 'Alice Mutton', 'Customer': 'BOLID', 'Qtr 4': '$1,170.00'}
# {'Product': 'Alice Mutton', 'Customer': 'BOTTM', 'Qtr 1': '$1,170.00'}
# {'Product': 'Alice Mutton', 'Customer': 'ERNSH', 'Qtr 1': '$1,123.20', 'Qtr 4': '$2,607.15'}
# {'Product': 'Alice Mutton', 'Customer': 'GODOS', 'Qtr 2': '$280.80'}
# {'Product': 'Alice Mutton', 'Customer': 'HUNGC', 'Qtr 1': '$62.40'}
# {'Product': 'Alice Mutton', 'Customer': 'PICCO', 'Qtr 2': '$1,560.00', 'Qtr 3': '$936.00'}
# {'Product': 'Alice Mutton', 'Customer': 'RATTC', 'Qtr 2': '$592.80'}
# {'Product': 'Alice Mutton', 'Customer': 'REGGC', 'Qtr 4': '$741.00'}
# {'Product': 'Alice Mutton', 'Customer': 'SAVEA', 'Qtr 3': '$3,900.00', 'Qtr 4': '$789.75'}
# {'Product': 'Alice Mutton', 'Customer': 'SEVES', 'Qtr 2': '$877.50'}
# {'Product': 'Alice Mutton', 'Customer': 'WHITC', 'Qtr 4': '$780.00'}
# ...

# %%
# Use pandas.DataFrame.from_dict() to Convert JSON to DataFrame

df = pd.DataFrame.from_dict(data['Source Data'])

# Print the DataFrame
print(df)
# Out:
#            Product Customer    Qtr 2      Qtr 1      Qtr 4    Qtr 3
# 0     Alice Mutton    ANTON  $702.00        NaN        NaN      NaN
# 1     Alice Mutton    BERGS      NaN    $312.00        NaN      NaN
# 2     Alice Mutton    BOLID      NaN        NaN  $1,170.00      NaN
# 3     Alice Mutton    BOTTM      NaN  $1,170.00        NaN      NaN
# 4     Alice Mutton    ERNSH      NaN  $1,123.20  $2,607.15      NaN
# ..             ...      ...      ...        ...        ...      ...
# 942  Zaanse koeken    MORGK      NaN        NaN    $114.00      NaN
# 943  Zaanse koeken    OTTIK      NaN        NaN        NaN  $380.00
# 944  Zaanse koeken    QUICK      NaN    $418.00        NaN      NaN
# 945  Zaanse koeken    SAVEA      NaN        NaN    $356.25   $95.00
# 946  Zaanse koeken    WELLI      NaN        NaN        NaN  $142.50
#
# [947 rows x 6 columns]
